# %%
import re
from ukr.wfst import apply_fst_text, graph

with open('/Users/vasyl/Downloads/voa_clean_text.txt', 'r') as file:
    for l in file:
        if 'цілих' not in l:
            continue

        l = l.replace("'", "")
        output = apply_fst_text(l, graph)
        if re.search('\d+', output):
            print(output)
            print(l)
# Out:
# ми не хотіли нічого марнувати тож завели алігаторіві тримали це у таємниці цілих 15 хвилин
# ми не хотіли нічого марнувати тож завели алігаторіві тримали це у таємниці цілих пятнадцять хвилин
#
# економіка шау 2020 першому році зросла на 5.7 відсотка повідомила у своєму звіті у четвер бюджетний бюро конгресом
# економіка шау дві тисячі двадцять першому році зросла на пять цілих сім десятих відсотка повідомила у своєму звіті у четвер бюджетний бюро конгресом
#
# світ бачить що відбувається і ті 6.8 мільйонів людей яких
# світ бачить що відбувається і ті шість цілих вісім десятих мільйонів людей яких
#
# 3.8 мільярда доларів
# три цілих і вісімдесятих мільярда доларів
#
# світ бачить що відбувається і ті 6.8 мільйонів людей яких
# світ бачить що відбувається і ті шість цілих вісім десятих мільйонів людей яких
#
# російський ринок відео ігор займає восьме місце у світі за доходом це складало 2.7 мільярда доларів у 1020 першому році
# ...
